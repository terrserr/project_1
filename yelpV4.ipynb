# %%
import requests
from pprint import pprint
import pandas as pd
import numpy as np
import requests
import json
from config import yelp_key
from yelpapi import YelpAPI
from config import austin_key

# %%
cities_df = pd.read_csv("C:/Users/Teresa Barajas/Anaconda/Anaconda3/envs/API/cities.csv")
cities_df.head()
# Out:
#   Metropolitan Statistical Area  Population
# 0                      San Juan     2157729
# 1                     Fairbanks       34657
# 2                       Detroit     1747582
# 3                   New Orleans     1272995
# 4                       Memphis     1346931

# %%
city_list= []
num_bar_list =[]
country_list= []
num_parks_list =[]
num_galleries_list=[]
num_gyms_list=[]
num_churches_list=[]
num_bookstore_list=[]
num_fastfood_list=[]

# %%
yelp_api = YelpAPI(austin_key)
search_results = yelp_api.search_query(term="fast food", location="new orleans", radius = 40000)

# %%
pprint(search_results)
# Out:
# {'businesses': [{'alias': 'golden-chips-new-orleans',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'}],
#                  'coordinates': {'latitude': 29.956566230081,
#                                  'longitude': -90.0642547220655},
#                  'display_phone': '(504) 510-5844',
#                  'distance': 1880.9353142984148,
#                  'id': 'rHW2kGOYzUIJWKia5ao-6Q',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_L0VEuKsM_fDKYNVI9HSLA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '537 Toulouse St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'New Orleans',
#                               'country': 'US',
#                               'display_address': ['537 Toulouse St',
#                                                   'New Orleans, LA 70130'],
# ...

# %%
print(search_results['total'])
# Out:
# 660

# %%
# use iterrows to iterate through pandas dataframe
for index, row in cities_df.iterrows():

    # get restaurant type from df
    place = row['Metropolitan Statistical Area']

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {place}.")
    
       
    try:
        response = yelp_api.search_query(term="bars", location=place, radius = 40000)
        print(f"The amount of bars in {place} is {response['total']}.")
        city_list.append(response["businesses"][0]["location"]["city"])
        country_list.append(response["businesses"][0]["location"]["country"])
        num_bar_list.append(response["total"])
    except (Exception):
            print("Missing field/result... skipping.")
    print("------------")
# Out:
# Retrieving Results for Index 0: San Juan.
# The amount of bars in San Juan is 344.
# ------------
# Retrieving Results for Index 1: Fairbanks.
# The amount of bars in Fairbanks is 34.
# ------------
# Retrieving Results for Index 2: Detroit.
# The amount of bars in Detroit is 1200.
# ------------
# Retrieving Results for Index 3: New Orleans.
# The amount of bars in New Orleans is 841.
# ------------
# Retrieving Results for Index 4: Memphis.
# The amount of bars in Memphis is 283.
# ------------
# Retrieving Results for Index 5: Mobile.
# The amount of bars in Mobile is 127.
# ------------
# Retrieving Results for Index 6: Philadelphia.
# The amount of bars in Philadelphia is 1700.
# ------------
# Retrieving Results for Index 7: Baltimore.
# The amount of bars in Baltimore is 933.
# ------------
# Retrieving Results for Index 8: Savannah.
# The amount of bars in Savannah is 269.
# ------------
# Retrieving Results for Index 9: Auburn.
# The amount of bars in Auburn is 43.
# ...

# %%
print(len(city_list))
# Out:
# 380

# %%
print(len(country_list))
# Out:
# 380

# %%
print(len(num_bar_list))
# Out:
# 380

# %%
# use iterrows to iterate through pandas dataframe and find #of parks
for index, row in cities_df.iterrows():

    # get restaurant type from df
    place = row['Metropolitan Statistical Area']

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {place}.")
    
    
    
    try:
        response = yelp_api.search_query(term="parks", location=place, radius = 40000)
        print(f"The amount of parks in {place} is {response['total']}.")
        num_parks_list.append(response["total"])
    except (Exception):
            print("Missing field/result... skipping.")
    print("------------")
# Out:
# Retrieving Results for Index 0: San Juan.
# The amount of parks in San Juan is 32.
# ------------
# Retrieving Results for Index 1: Fairbanks.
# The amount of parks in Fairbanks is 4.
# ------------
# Retrieving Results for Index 2: Detroit.
# The amount of parks in Detroit is 219.
# ------------
# Retrieving Results for Index 3: New Orleans.
# The amount of parks in New Orleans is 134.
# ------------
# Retrieving Results for Index 4: Memphis.
# The amount of parks in Memphis is 76.
# ------------
# Retrieving Results for Index 5: Mobile.
# The amount of parks in Mobile is 28.
# ------------
# Retrieving Results for Index 6: Philadelphia.
# The amount of parks in Philadelphia is 421.
# ------------
# Retrieving Results for Index 7: Baltimore.
# The amount of parks in Baltimore is 228.
# ------------
# Retrieving Results for Index 8: Savannah.
# The amount of parks in Savannah is 76.
# ------------
# Retrieving Results for Index 9: Auburn.
# The amount of parks in Auburn is 12.
# ...

# %%
print(len(num_parks_list))
# Out:
# 380

# %%
# use iterrows to iterate through pandas dataframe and find #of galleries
for index, row in cities_df.iterrows():

    # get restaurant type from df
    place = row['Metropolitan Statistical Area']

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {place}.")
    
    
    
    try:
        response = yelp_api.search_query(term="gallery", location=place, radius = 40000)
        print(f"The amount of galleries in {place} is {response['total']}.")
        num_galleries_list.append(response["total"])
    except (Exception):
            print("Missing field/result... skipping.")
    print("------------")
# Out:
# Retrieving Results for Index 0: San Juan.
# The amount of galleries in San Juan is 19.
# ------------
# Retrieving Results for Index 1: Fairbanks.
# The amount of galleries in Fairbanks is 7.
# ------------
# Retrieving Results for Index 2: Detroit.
# The amount of galleries in Detroit is 139.
# ------------
# Retrieving Results for Index 3: New Orleans.
# The amount of galleries in New Orleans is 248.
# ------------
# Retrieving Results for Index 4: Memphis.
# The amount of galleries in Memphis is 42.
# ------------
# Retrieving Results for Index 5: Mobile.
# The amount of galleries in Mobile is 20.
# ------------
# Retrieving Results for Index 6: Philadelphia.
# The amount of galleries in Philadelphia is 317.
# ------------
# Retrieving Results for Index 7: Baltimore.
# The amount of galleries in Baltimore is 123.
# ------------
# Retrieving Results for Index 8: Savannah.
# The amount of galleries in Savannah is 70.
# ------------
# Retrieving Results for Index 9: Auburn.
# ...

# %%
print(len(num_galleries_list))
# Out:
# 380

# %%
# use iterrows to iterate through pandas dataframe and find #of gyms
for index, row in cities_df.iterrows():

    # get restaurant type from df
    place = row['Metropolitan Statistical Area']

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {place}.")
    
    
    
    try:
        response = yelp_api.search_query(term="gym", location=place, radius = 40000)
        print(f"The amount of gyms in {place} is {response['total']}.")
        num_gyms_list.append(response["total"])
    except (Exception):
            print("Missing field/result... skipping.")
    print("------------")
# Out:
# Retrieving Results for Index 0: San Juan.
# The amount of gyms in San Juan is 44.
# ------------
# Retrieving Results for Index 1: Fairbanks.
# The amount of gyms in Fairbanks is 11.
# ------------
# Retrieving Results for Index 2: Detroit.
# The amount of gyms in Detroit is 684.
# ------------
# Retrieving Results for Index 3: New Orleans.
# The amount of gyms in New Orleans is 290.
# ------------
# Retrieving Results for Index 4: Memphis.
# The amount of gyms in Memphis is 172.
# ------------
# Retrieving Results for Index 5: Mobile.
# The amount of gyms in Mobile is 63.
# ------------
# Retrieving Results for Index 6: Philadelphia.
# The amount of gyms in Philadelphia is 1300.
# ------------
# Retrieving Results for Index 7: Baltimore.
# The amount of gyms in Baltimore is 682.
# ------------
# Retrieving Results for Index 8: Savannah.
# The amount of gyms in Savannah is 106.
# ------------
# Retrieving Results for Index 9: Auburn.
# The amount of gyms in Auburn is 16.
# ...

# %%
print(len(num_gyms_list))
# Out:
# 380

# %%
# use iterrows to iterate through pandas dataframe and find #of churches
for index, row in cities_df.iterrows():

    # get restaurant type from df
    place = row['Metropolitan Statistical Area']

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {place}.")
    
    
    
    try:
        response = yelp_api.search_query(term="church", location=place, radius = 40000)
        print(f"The amount of churches in {place} is {response['total']}.")
        num_churches_list.append(response["total"])
    except (Exception):
            print("Missing field/result... skipping.")
    print("------------")
# Out:
# Retrieving Results for Index 0: San Juan.
# The amount of churches in San Juan is 20.
# ------------
# Retrieving Results for Index 1: Fairbanks.
# The amount of churches in Fairbanks is 6.
# ------------
# Retrieving Results for Index 2: Detroit.
# The amount of churches in Detroit is 253.
# ------------
# Retrieving Results for Index 3: New Orleans.
# The amount of churches in New Orleans is 109.
# ------------
# Retrieving Results for Index 4: Memphis.
# The amount of churches in Memphis is 89.
# ------------
# Retrieving Results for Index 5: Mobile.
# The amount of churches in Mobile is 35.
# ------------
# Retrieving Results for Index 6: Philadelphia.
# The amount of churches in Philadelphia is 320.
# ------------
# Retrieving Results for Index 7: Baltimore.
# The amount of churches in Baltimore is 216.
# ------------
# Retrieving Results for Index 8: Savannah.
# The amount of churches in Savannah is 44.
# ------------
# Retrieving Results for Index 9: Auburn.
# ...

# %%
print(len(num_churches_list))
# Out:
# 380

# %%
# use iterrows to iterate through pandas dataframe and find #of bookstores
for index, row in cities_df.iterrows():

    # get restaurant type from df
    place = row['Metropolitan Statistical Area']

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {place}.")
    
    
    
    try:
        response = yelp_api.search_query(term="bookstore", location=place, radius = 40000)
        print(f"The amount of bookstores in {place} is {response['total']}.")
        num_bookstore_list.append(response["total"])
    except (Exception):
            print("Missing field/result... skipping.")
    print("------------")
# Out:
# Retrieving Results for Index 0: San Juan.
# The amount of bookstores in San Juan is 12.
# ------------
# Retrieving Results for Index 1: Fairbanks.
# The amount of bookstores in Fairbanks is 4.
# ------------
# Retrieving Results for Index 2: Detroit.
# The amount of bookstores in Detroit is 154.
# ------------
# Retrieving Results for Index 3: New Orleans.
# The amount of bookstores in New Orleans is 82.
# ------------
# Retrieving Results for Index 4: Memphis.
# The amount of bookstores in Memphis is 35.
# ------------
# Retrieving Results for Index 5: Mobile.
# The amount of bookstores in Mobile is 10.
# ------------
# Retrieving Results for Index 6: Philadelphia.
# The amount of bookstores in Philadelphia is 262.
# ------------
# Retrieving Results for Index 7: Baltimore.
# The amount of bookstores in Baltimore is 142.
# ------------
# Retrieving Results for Index 8: Savannah.
# The amount of bookstores in Savannah is 29.
# ------------
# Retrieving Results for Index 9: Auburn.
# ...

# %%
print(len(num_bookstore_list))
# Out:
# 380

# %%
# use iterrows to iterate through pandas dataframe and find #of fastfood
for index, row in cities_df.iterrows():

    # get restaurant type from df
    place = row['Metropolitan Statistical Area']

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {place}.")
    
    
    
    try:
        response = yelp_api.search_query(term="fast food", location=place, radius = 40000)
        print(f"The amount of fast food restaurants in {place} is {response['total']}.")
        num_fastfood_list.append(response["total"])
    except (Exception):
            print("Missing field/result... skipping.")
    print("------------")
# Out:
# Retrieving Results for Index 0: San Juan.
# The amount of fast food restaurants in San Juan is 122.
# ------------
# Retrieving Results for Index 1: Fairbanks.
# The amount of fast food restaurants in Fairbanks is 33.
# ------------
# Retrieving Results for Index 2: Detroit.
# The amount of fast food restaurants in Detroit is 1900.
# ------------
# Retrieving Results for Index 3: New Orleans.
# The amount of fast food restaurants in New Orleans is 660.
# ------------
# Retrieving Results for Index 4: Memphis.
# The amount of fast food restaurants in Memphis is 704.
# ------------
# Retrieving Results for Index 5: Mobile.
# The amount of fast food restaurants in Mobile is 266.
# ------------
# Retrieving Results for Index 6: Philadelphia.
# The amount of fast food restaurants in Philadelphia is 1600.
# ------------
# Retrieving Results for Index 7: Baltimore.
# The amount of fast food restaurants in Baltimore is 1500.
# ------------
# Retrieving Results for Index 8: Savannah.
# ...

# %%
print(len(num_fastfood_list))
# Out:
# 380

# %%
yelp_results_df = pd.DataFrame({
    "city":city_list, 
    "country": country_list, 
    "# of Bars":num_bar_list, 
    "# of parks":num_parks_list, 
    "# of galleries":num_galleries_list, 
    "# of gyms":num_gyms_list,
    "# of bookstores":num_bookstore_list, 
    "# of fast food restaurants":num_fastfood_list})

# %%
yelp_results_df.head()
# Out:
#           city country  # of Bars  # of parks  # of galleries  # of gyms  \
# 0     San Juan      PR        344          32              19         44
# 1    Fairbanks      US         34           4               7         11
# 2      Detroit      US       1200         219             139        684
# 3  New Orleans      US        841         134             248        290
# 4      Memphis      US        283          76              42        172
#
#    # of bookstores  # of fast food restaurants
# 0               12                         122
# 1                4                          33
# 2              154                        1900
# 3               82                         660
# 4               35                         704

# %%
yelp_results_df.to_csv('C:/Users/Teresa Barajas/Anaconda/Anaconda3/envs/API/yelp_results.csv')
